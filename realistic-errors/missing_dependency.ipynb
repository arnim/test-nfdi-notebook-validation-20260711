# %%
print('Preparing dependency-based analysis')
sample_size = 250
assert sample_size > 0

# %%
# Simulates a dependency that disappeared or was omitted from requirements.txt
import nfdi_validation_package_that_does_not_exist

# %%
print('This cell must not execute after the failed import')

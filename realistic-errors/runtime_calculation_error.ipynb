# %%
print('Preparing rate calculation')
event_counts = [10, 5, 0]

# %%
# A realistic data-dependent runtime error
rates = [100 / count for count in event_counts]
print(rates)

# %%
print('This cell must not execute after division by zero')
